# %% [markdown]
# # Flux Data Demo
#
# This little demo uses `terndata.flux` library to access Flux Data directly from TERN Data services.
#
# * Documentation: https://terndata-flux.readthedocs.io
# * GitHub: https://github.com/ternaustralia/terndata.flux/
# * PyPi: https://pypi.org/project/terndata.flux/
#
# ## Data links
#
# * Metadata: https://portal.tern.org.au/results?theme=flux
# * Thredds: https://dap.tern.org.au/thredds/catalog/ecosystem_process/ozflux/catalog.html
# * Download: https://data.tern.org.au/EcosystemProcesses/ozflux/
#
# ⚠️ Important: To access data programmatically, you need to create an TERN API key: https://account.tern.org.au/
#
# Once you created an api key, create a .netrc file in your home directory (cd ~, vim .netrc), then copy the following into the file, replacing YOUR_REAL_API_KEY with your key copied from https://account.tern.org.au/
#
#     machine data.tern.org.au
#         login apikey
#         password YOUR_REAL_API_KEY

# %%
# set to true to enable hvplots (disabled to keep .ipynb file size small)
USE_HV_PLOT = False
import terndata.flux as flux
if USE_HV_PLOT:
    import hvplot.xarray
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# # Discovery
#
# The library offers a few helper methods to discover available data sets.

# %%
# get all available sites and show on map
sites = flux.get_sites().set_crs("EPSG:4326")
sites
# Out:
#                                  site   longitude   latitude  \
# 0                       AdelaideRiver  131.117800 -13.076900
# 1                   AliceSpringsMulga  133.249000 -22.283000
# 2                      AlpinePeatland  147.320833 -36.862222
# 3                             Boyagin  116.938559 -32.477093
# 4                    CalperumChowilla  140.587700 -34.002700
# 5                     CapeTribulation  145.446922 -16.103219
# 6                              Collie  116.237000 -33.420000
# 7                              CowBay  145.427150 -16.238189
# 8                     CumberlandPlain  150.723611 -33.615278
# 9                         DalyPasture  131.318100 -14.063300
# 10                      DalyUncleared  131.388100 -14.159200
# 11                    DigbyPlantation  141.616472 -37.882694
# 12                           DryRiver  132.370600 -15.258800
# 13                            Emerald  148.474600 -23.858720
# 14                       Fletcherview  146.189138 -19.887285
# 15                            FoggDam  131.307200 -12.545200
# 16                       GatumPasture  141.960897 -37.390033
# 17                             Gingin  115.713770 -31.376351
# 18              GreatWesternWoodlands  120.654167 -30.191400
# 19                      HowardSprings  131.150050 -12.495200
# 20                         Litchfield  130.794546 -13.179042
# 21    LongreachMitchellGrassRangeland  144.310416 -23.523266
# 22                             Loxton  140.655120 -34.470350
# 23                         MyallValeA  150.020000 -30.543000
# 24                         MyallValeB  150.090000 -30.697000
# 25                              Otway  142.810000 -38.525000
# 26                   RedDirtMelonFarm  132.477567 -14.563639
# 27                         Ridgefield  116.966827 -32.506102
# 28                         RiggsCreek  145.576000 -36.656000
# 29                        RobsonCreek  145.630137 -17.117469
# 30  SamfordEcologicalResearchFacility  152.877780 -27.388060
# 31                       SilverPlains  147.087500 -42.090556
# 32                            SnowGum  148.435850 -36.375649
# 33                        SturtPlains  133.350200 -17.150700
# 34                         TiTreeEast  133.249000 -22.283000
# 35                         Tumbarumba  148.151600 -35.656600
# 36                       WallabyCreek  145.187800 -37.425900
# 37                              Warra  146.654520 -43.095020
# 38                         Wellington  148.984300 -32.572700
# 39                              Whroo  145.029400 -36.673200
# 40                  WombatStateForest  144.094046 -37.422506
# 41                              Yanco  146.290800 -34.987800
# 42                  YarramundiControl  150.734864 -33.613469
# 43                YarramundiIrrigated  150.763284 -33.620812
#
#                                            vegetation  \
# 0                                       Woody Savanna
# 1   Canopy + three types of understorey (vegetatio...
# 2
# 3                           Dry schlerophyll woodland
# 4                                              Mallee
# 5               lowland complex mesophyll vine forest
# 6                           Dry schlerophyll woodland
# 7               lowland complex mesophyll vine forest
# 8                              Dry sclerophyll forest
# 9                           Tropical improved pasture
# 10                                      Woody Savanna
# 11                     Eucalyptus globulus (blue gum)
# 12                                   Woodland savanna
# 13                                    Mallee and crop
# 14                                  Semi-arid savanna
# 15                         Ephemeral tropical wetland
# 16                   Phalaris and Subterranean Clover
# 17                                   Banksia woodland
# 18                           sparse eucalypt woodland
# 19                                      Woody savanna
# 20                                      Woody savanna
# 21                                     Mitchell Grass
# 22                                     Almond orchard
# 23
# 24
# 25                                    Pasture, grazed
# 26                        Woody savannah then cleared
# 27                                              Wheat
# 28                                            Pasture
# 29  Regional Ecosystem (RE) 7.3.36a, complex mesop...
# 30                                            pasture
# 31          Species rich highland grassland/sedgeland
# 32                                Sub-alpine woodland
# 33                                Mitchell Grasslands
# 34  Canopy + three types of understorey (vegetatio...
# 35                             wet sclerophyll forest
# 36                                       Mountain Ash
# 37                     Eucalyptus obliqua tall forest
# 38                                            Pasture
# 39                          Dry schlerophyll woodland
# 40                    dry sclerophyll eucalypt forest
# 41                                            Pasture
# 42                               pasture, unirrigated
# 43                                 pasture, irrigated
#
#                  canopy height                start                  end  \
# 0                        16.4m  2007-10-17 11:30:00  2009-05-24 06:00:00
# 1                         6.5m  2010-09-03 00:00:00  2025-01-28 10:00:00
# 2                         0.3m  2017-04-12 18:30:00  2022-06-20 23:30:00
# 3                        13.0m  2017-10-20 13:00:00  2025-02-02 00:00:00
# 4                           3m  2010-07-30 11:00:00  2025-02-02 00:00:00
# 5                          25m  2010-01-01 00:00:00  2018-11-02 12:00:00
# 6                        12.0m  2017-08-04 00:30:00  2019-11-11 13:30:00
# 7                          26m  2009-01-01 09:00:00  2025-02-02 00:00:00
# 8                         24 m  2014-01-01 00:30:00  2025-01-01 00:00:00
# 9                         0.5m  2008-01-01 00:00:00  2013-09-08 13:30:00
# 10                       16.4m  2008-01-01 00:00:00  2025-02-02 00:00:00
# 11                         +6m  2018-01-01 00:30:00  2021-07-07 12:00:00
# 12                       0.15m  2009-10-25 15:00:00  2025-02-02 00:00:00
# 13                    0.2-0.6m  2011-06-10 00:30:00  2013-12-31 23:30:00
# 14                         12m  2022-01-22 22:00:00  2025-01-17 00:00:00
# 15                        0.5m  2006-02-07 00:00:00  2008-10-31 17:30:00
# 16                       0.05m  2015-02-09 00:30:00  2021-12-31 23:30:00
# 17                        6.8m  2011-10-13 14:00:00  2024-12-31 23:30:00
# 18                          18  2013-01-01 15:30:00  2024-12-31 23:30:00
# 19                         16m  2002-01-01 06:00:00  2025-02-02 00:00:00
# 20                         16m  2015-06-23 13:00:00  2025-01-17 00:00:00
# 21                       0.50m  2018-10-09 12:00:00  2024-07-01 00:00:00
# 22  5.5m (Stevens et al. 2012)  2008-08-19 17:00:00  2009-06-09 10:30:00
# 23                        0.5m  2023-11-29 10:00:00  2025-01-17 00:00:00
# 24                        0.5m  2023-11-28 13:30:00  2025-01-17 00:00:00
# 25                       0.1 m  2007-08-11 00:00:00  2011-01-01 00:00:00
# 26                    variable  2011-09-23 09:00:00  2013-07-21 23:30:00
# 27                          1m  2015-03-29 05:00:00  2025-02-02 00:00:00
# 28                        0.4m  2011-01-01 00:30:00  2017-07-12 17:30:00
# 29                         28m  2013-08-01 17:30:00  2025-02-02 00:00:00
# 30                        0.5m  2010-06-02 12:00:00  2017-12-31 14:30:00
# 31                        0.1m  2019-12-05 10:00:00  2024-12-31 23:30:00
# 32                          8m  2023-12-27 15:30:00  2025-01-17 00:00:00
# 33                        0.5m  2008-08-28 11:00:00  2025-02-02 00:00:00
# 34                        6.5m  2012-07-18 00:00:00  2022-01-17 23:30:00
# 35                        40 m  2002-01-07 16:00:00  2022-12-03 18:00:00
# 36                        100m  2005-08-25 12:30:00  2008-12-31 23:30:00
# 37                         55m  2013-03-05 15:00:00  2021-09-21 12:00:00
# 38                        0.5m  2023-09-27 12:30:00  2025-01-17 00:00:00
# 39                       28.0m  2011-12-01 13:30:00  2023-12-31 23:30:00
# 40                        23 m  2024-05-08 14:30:00  2025-02-02 00:00:00
# 41                        0.50  2012-10-24 14:00:00  2025-01-28 03:00:00
# 42                       0.5 m  2019-10-22 15:30:00  2025-01-01 00:00:00
# 43                       0.5 m  2019-10-15 09:30:00  2024-12-29 12:00:00
#
#                        geometry
# 0     POINT (131.1178 -13.0769)
# 1       POINT (133.249 -22.283)
# 2   POINT (147.32083 -36.86222)
# 3   POINT (116.93856 -32.47709)
# 4     POINT (140.5877 -34.0027)
# 5   POINT (145.44692 -16.10322)
# 6        POINT (116.237 -33.42)
# 7   POINT (145.42715 -16.23819)
# 8   POINT (150.72361 -33.61528)
# 9     POINT (131.3181 -14.0633)
# 10    POINT (131.3881 -14.1592)
# 11  POINT (141.61647 -37.88269)
# 12    POINT (132.3706 -15.2588)
# 13   POINT (148.4746 -23.85872)
# 14  POINT (146.18914 -19.88728)
# 15    POINT (131.3072 -12.5452)
# 16   POINT (141.9609 -37.39003)
# 17  POINT (115.71377 -31.37635)
# 18   POINT (120.65417 -30.1914)
# 19   POINT (131.15005 -12.4952)
# 20  POINT (130.79455 -13.17904)
# 21  POINT (144.31042 -23.52327)
# 22  POINT (140.65512 -34.47035)
# 23       POINT (150.02 -30.543)
# 24       POINT (150.09 -30.697)
# 25       POINT (142.81 -38.525)
# 26  POINT (132.47757 -14.56364)
# 27   POINT (116.96683 -32.5061)
# 28      POINT (145.576 -36.656)
# 29  POINT (145.63014 -17.11747)
# 30  POINT (152.87778 -27.38806)
# 31   POINT (147.0875 -42.09056)
# 32  POINT (148.43585 -36.37565)
# 33    POINT (133.3502 -17.1507)
# 34      POINT (133.249 -22.283)
# 35    POINT (148.1516 -35.6566)
# 36    POINT (145.1878 -37.4259)
# 37  POINT (146.65452 -43.09502)
# 38    POINT (148.9843 -32.5727)
# 39    POINT (145.0294 -36.6732)
# 40  POINT (144.09405 -37.42251)
# 41    POINT (146.2908 -34.9878)
# 42  POINT (150.73486 -33.61347)
# 43  POINT (150.76328 -33.62081)

# %%
# Filter the list of sites by name and plot on map
my_sites = ["AliceSpringsMulga", "CalperumChowilla", "HowardSprings"]
sites[sites.site.isin(my_sites)].explore(
    marker_kwds=dict(radius=5, fill=True)
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7dc03d2f1181f994e4d1869cb986b894 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7dc03d2f1181f994e4d1869cb986b894&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7dc03d2f1181f994e4d1869cb986b894 = L.map(
#                 &quot;map_7dc03d2f1181f994e4d1869cb986b894&quot;,
#                 {
#                     center: [-23.24895, 135.868875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_7dc03d2f1181f994e4d1869cb986b894);
#
#
#
#
#
#             var tile_layer_38d4422ac340c36c1fc5a711c73889c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38d4422ac340c36c1fc5a711c73889c5.addTo(map_7dc03d2f1181f994e4d1869cb986b894);
#
#
#             map_7dc03d2f1181f994e4d1869cb986b894.fitBounds(
#                 [[-34.0027, 131.15005], [-12.4952, 140.5877]],
#                 {}
#             );
#
#
#         function geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 5,
# };
#
#             let style = geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ea6fb9c8b3b508b26d31e729f0d491f0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ea6fb9c8b3b508b26d31e729f0d491f0 = L.geoJson(null, {
#                 onEachFeature: geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_onEachFeature,
#
#                 style: geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_styler,
#                 pointToLayer: geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_add (data) {
#             geo_json_ea6fb9c8b3b508b26d31e729f0d491f0
#                 .addData(data);
#         }
#             geo_json_ea6fb9c8b3b508b26d31e729f0d491f0_add({&quot;bbox&quot;: [131.15005, -34.0027, 140.5877, -12.4952], &quot;features&quot;: [{&quot;bbox&quot;: [133.249, -22.283, 133.249, -22.283], &quot;geometry&quot;: {&quot;coordinates&quot;: [133.249, -22.283], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;canopy height&quot;: &quot;6.5m&quot;, &quot;end&quot;: &quot;2025-01-28 10:00:00&quot;, &quot;latitude&quot;: -22.283, &quot;longitude&quot;: 133.249, &quot;site&quot;: &quot;AliceS

# %% [markdown]
# # Versioning
#
# Let's pick one site, and find a few more details about available data.
#
# Flux Data is released quarterly, and usually fully reprocessed. The version number indicate the quarterly release date.
#
# Older versions are kept for reproducibility.

# %%
# Which versions are available for Howard Springs ?
my_site = "HowardSprings"
versions = flux.get_versions(my_site)
versions
# Out:
# ['2020',
#  '2021_v1',
#  '2022_v1',
#  '2022_v2',
#  '2023_v1',
#  '2023_v2',
#  '2024_v1',
#  '2024_v2',
#  '2025_v1']

# %% [markdown]
# # Processing Levels
#
# Flux data is published at various processing levels.
#
# * L3: extensive quality control and formatting
# * L4: gap filling for meteorological data using external sources
# * L5: gap filling for flux data using artificial neural networks
# * L6: partitioning gap-filled data into Gross Primary Productivity (GPP) and Ecosystem Respiration (ER)

# %%
# pick latest and find available process
version = versions[-1]
p_levels = flux.get_processing_levels(my_site, version)
p_levels
# Out:
# ['L3', 'L4', 'L5', 'L6']

# %% [markdown]
# # Access Data
#
# The `flux.get_dataset` method loads data for a specific site, version and processing level into an xarray.
#
# The returned xarray provides all global and per variable metadata for the selected dataset.

# %%
# pick greatest processing level (L6)
p_level = p_levels[-1]
ds = flux.get_dataset(my_site, version, p_level)
ds
# Out:
# <xarray.Dataset> Size: 447MB
# Dimensions:                (time: 404773, latitude: 1, longitude: 1)
# Coordinates:
#   * time                   (time) datetime64[ns] 3MB 2002-01-01T06:00:00 ... ...
#   * latitude               (latitude) float64 8B -12.5
#   * longitude              (longitude) float64 8B 131.2
# Data variables: (12/182)
#     crs                    int32 4B ...
#     station_name           |S64 64B ...
#     AH                     (time, latitude, longitude) float64 3MB ...
#     AH_QCFlag              (time, latitude, longitude) int32 2MB ...
#     AH_HMP_23m             (time, latitude, longitude) float64 3MB ...
#     AH_HMP_23m_QCFlag      (time, latitude, longitude) int32 2MB ...
#     ...                     ...
#     Ws_SONIC_Av            (time, latitude, longitude) float64 3MB ...
#     Ws_SONIC_Av_QCFlag     (time, latitude, longitude) int32 2MB ...
#     ps                     (time, latitude, longitude) float64 3MB ...
#     ps_QCFlag              (time, latitude, longitude) int32 2MB ...
#     ustar                  (time, latitude, longitude) float64 3MB ...
#     ustar_QCFlag           (time, latitude, longitude) int32 2MB ...
# Attributes: (12/55)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     altitude:                 64m
#     canopy_height:            16m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     ...                       ...
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Howard Springs sit...
#     tower_height:             23m
#     vegetation:               Woody savanna
#     DODS.strlen:              13
#     DODS.dimName:             name_strlen

# %% [markdown]
# # Drop some dimensions
#
# The data is stored in a CF compliant data format, and has a latitude and longitude dimension. However a flux tower is stationary and has only a single value for location. We can drop these extra dimension to make working with the data a bit easier. (No need to address coordinates all the time).

# %%
# remove single value dimensions
ds = ds.squeeze(drop=True)
ds
# Out:
# <xarray.Dataset> Size: 447MB
# Dimensions:                (time: 404773)
# Coordinates:
#   * time                   (time) datetime64[ns] 3MB 2002-01-01T06:00:00 ... ...
# Data variables: (12/182)
#     crs                    int32 4B ...
#     station_name           |S64 64B ...
#     AH                     (time) float64 3MB ...
#     AH_QCFlag              (time) int32 2MB ...
#     AH_HMP_23m             (time) float64 3MB ...
#     AH_HMP_23m_QCFlag      (time) int32 2MB ...
#     ...                     ...
#     Ws_SONIC_Av            (time) float64 3MB ...
#     Ws_SONIC_Av_QCFlag     (time) int32 2MB ...
#     ps                     (time) float64 3MB ...
#     ps_QCFlag              (time) int32 2MB ...
#     ustar                  (time) float64 3MB ...
#     ustar_QCFlag           (time) int32 2MB ...
# Attributes: (12/55)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     altitude:                 64m
#     canopy_height:            16m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     ...                       ...
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Howard Springs sit...
#     tower_height:             23m
#     vegetation:               Woody savanna
#     DODS.strlen:              13
#     DODS.dimName:             name_strlen

# %% [markdown]
# # Absolute Humidity
#
# Let's filter out some variables we may be interested in.

# %%
# ahs = ds.filter_by_attrs(long_name="Absolute humidity")
ahs = ds.filter_by_attrs(standard_name="mass_concentration_of_water_vapor_in_air")
ahs
# Out:
# <xarray.Dataset> Size: 16MB
# Dimensions:     (time: 404773)
# Coordinates:
#   * time        (time) datetime64[ns] 3MB 2002-01-01T06:00:00 ... 2025-02-02
# Data variables:
#     AH          (time) float64 3MB ...
#     AH_HMP_23m  (time) float64 3MB ...
#     AH_HMP_2m   (time) float64 3MB ...
#     AH_IRGA_Av  (time) float64 3MB ...
# Attributes: (12/55)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     altitude:                 64m
#     canopy_height:            16m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     ...                       ...
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Howard Springs sit...
#     tower_height:             23m
#     vegetation:               Woody savanna
#     DODS.strlen:              13
#     DODS.dimName:             name_strlen

# %%
# remove all values > 0 and average daily
ahs = ahs.where(ahs > 0).resample(time="1D").mean()

# %%
with plt.ioff():
    ahs.to_array().plot.line(figsize=(10,5), hue="variable")
    plt.savefig("images/flux_ahs.png");
    plt.close()

# %% [markdown]
# ![AHS Plot](./images/flux_ahs.png)

# %%
# interactive hvplot
if USE_HV_PLOT:
    ahs.hvplot(width=1000, height=600)

# %% [markdown]
# # Air Temperature

# %%
# Temperature
tas = ds.filter_by_attrs(standard_name="air_temperature")
tas = tas.where(tas > -20).resample(time="1D").mean()

# %%
with plt.ioff():
    tas.to_array().plot.line(figsize=(10,5), hue="variable")
    plt.savefig("images/flux_tas.png");
    plt.close()

# %% [markdown]
# ![Ta Plot](./images/flux_tas.png)

# %%
# interactive hvplot
if USE_HV_PLOT:
    tas.hvplot(width=1000, height=600)

# %% [markdown]
# # Gross Primary Productivity

# %%
gpp = ds.filter_by_attrs(long_name="Gross Primary Productivity")
gpp = gpp.where(gpp >= 0).resample(time="1D").mean()

# %%
with plt.ioff():
    gpp.to_array().plot.line(figsize=(10,5), hue="variable")
    plt.savefig("images/flux_gpp.png");
    plt.close()

# %% [markdown]
# ![GPP Plot](./images/flux_gpp.png)

# %%
# interactive hvplot
if USE_HV_PLOT:
    gpp.hvplot(width=1000, height=600)

# %% [markdown]
# # Compare across sites
#
# We can also load data from multiple sites in one go and compare similar variables.
#
# One has to be careful though, as not every site has data published for the same version.

# %%
# Do this across sites
dss = flux.get_datasets(my_sites, version)
# get air temperature for all sites 
dss = {key: value.Ta.squeeze(drop=True) for key, value in dss.items()}
dss
# Out:
# {'AliceSpringsMulga': <xarray.DataArray 'Ta' (time: 252549)> Size: 2MB
#  [252549 values with dtype=float64]
#  Coordinates:
#    * time     (time) datetime64[ns] 2MB 2010-09-03 ... 2025-01-28T10:00:00
#  Attributes:
#      coverage_L3:     87%
#      height:          11.6m
#      instrument:      HMP45c
#      long_name:       Air temperature
#      standard_name:   air_temperature
#      statistic_type:  average
#      units:           degC
#      valid_range:     [-5. 50.],
#  'CalperumChowilla': <xarray.DataArray 'Ta' (time: 255810)> Size: 2MB
#  [255810 values with dtype=float64]
#  Coordinates:
#    * time     (time) datetime64[ns] 2MB 2010-07-30T11:00:00 ... 2025-03-02T19:...
#  Attributes:
#      coverage_L3:     97%
#      height:          2m
#      instrument:      HMP45C,HMP60
#      long_name:       Air temperature
#      standard_name:   air_temperature
#      statistic_type:  average
#      units:           degC
#      valid_range:     [ 0. 50.],
#  'HowardSprings': <xarray.DataArray 'Ta' (time: 406314)> Size: 3MB
#  [406314 values with dtype=float64]
#  Coordinates:
#    * time     (time) datetime64[ns] 3MB 2002-01-01T06:00:00 ... 2025-03-06T02:...
#  Attributes:
#      coverage_L3:     88%
#      height:          23m
#      instrument:      HMP45C
#      long_name:       Air temperature
#      standard_name:   air_temperature
#      statistic_type:  average
#      units:           degC
#      valid_range:     [ 0. 40.]}

# %%
# filter all variables by valid value range (remove outliers)
dss = {key: value.where((value > value.attrs["valid_range"][0]) & (value < value.attrs["valid_range"][1])) for key,value in dss.items()}

# %%
# create an xarray dataset combining all datasets
da = xr.Dataset(dss)
da
# Out:
# <xarray.Dataset> Size: 13MB
# Dimensions:            (time: 406314)
# Coordinates:
#   * time               (time) datetime64[ns] 3MB 2002-01-01T06:00:00 ... 2025...
# Data variables:
#     AliceSpringsMulga  (time) float64 3MB nan nan nan nan ... nan nan nan nan
#     CalperumChowilla   (time) float64 3MB nan nan nan nan ... nan nan nan nan
#     HowardSprings      (time) float64 3MB 24.14 24.18 24.43 ... 27.56 27.23

# %%
# plot Air temperature for all sites monthly averagre
with plt.ioff():
    da.resample(time="1ME").mean().to_array().plot.line(figsize=(10,5), hue="variable")
    plt.savefig("images/flux_tac.png");
    plt.close()

# %% [markdown]
# ![Ta comparison](images/flux_tac.png)

# %%
# plot Air temperature for all sites monthly average - interactive hvplot
if USE_HV_PLOT:
    da.resample(time="1ME").mean().hvplot(width=1000, height=600)

# %%
# slice dataset over given time area, and plot daily averages
with plt.ioff():
    da.sel(time=slice("2020-01-01", "2020-12-12")).resample(time="1D").mean().to_array().plot.line(figsize=(10,5), hue="variable")
    plt.savefig("images/flux_tac_2020.png");
    plt.close()

# %% [markdown]
# ![Ta 2020 comparison](images/flux_tac_2020.png)

# %%
# slice dataset over given time area, and plot daily averages - interactive hvplot
if USE_HV_PLOT:
    da.sel(time=slice("2020-01-01", "2020-12-12")).resample(time="1D").mean().hvplot(width=1000, height=600)
